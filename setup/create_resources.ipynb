# %% [markdown]
# ## Create Catalog

# %%
# %sql
CREATE CATALOG IF NOT EXISTS beverage_sales;

# %% [markdown]
# ## Create Schemas

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS beverage_sales.bronze;

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS beverage_sales.silver;

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS beverage_sales.gold;

# %% [markdown]
# ## Create Volume

# %%
# %sql
CREATE VOLUME IF NOT EXISTS beverage_sales.bronze.raw_data;
